# %% [markdown]
# <a href="https://colab.research.google.com/github/AmirHosseinAlikhahMishamandani/Hackerrank/blob/main/HRC_10_timeConversion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # hackerrank.com
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Solution

# %%
import math
import os
import random
import re
import sys

def timeConversion(s):
    if 'AM' in s:
        s = s.replace('AM', "")
        if '12' in s:
            s = s.replace('12', "00")
            return s
        else:
            return s
    elif 'PM' in s:
        s = s.replace('PM', "")
        if '12' in s:
            return s
        else:
            s = s.replace(s[0:2], str(int(s[0:2])+12))
            return s

hour = random.randint(1, 12)
minute = random.randint(0, 59)
second = random.randint(0, 59)
am_pm = random.choice(["AM", "PM"])

given_time = f"{hour:02d}:{minute:02d}:{second:02d}{am_pm}"

print(f'The military time for the given time {given_time} is {timeConversion(given_time)}')
# Out:
# The military time for the given time 06:01:09AM is 06:01:09
