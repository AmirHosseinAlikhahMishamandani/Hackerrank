# %% [markdown]
# <a href="https://colab.research.google.com/github/AmirHosseinAlikhahMishamandani/Hackerrank/blob/main/HRC_15_kangaroo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # hackerrank.com
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Solution

# %%
import math
import os
import random
import re
import sys

def kangaroo(x1, v1, x2, v2):
    if v1 == v2:
        if x1 == x2:
            return 'YES'
        else:
            return 'NO'
    else:
        t = (x2 - x1) / (v1 - v2)
        if t >= 0 and t.is_integer():
            return 'YES'
        else:
            return 'NO'

print('\nCase 1:\n')
x1, v1, x2, v2 = 0, 3, 4, 2
print(f'{kangaroo(x1, v1, x2, v2)}')

print('\nCase 2:\n')
x1, v1, x2, v2 = 0, 2, 5, 3
print(f'{kangaroo(x1, v1, x2, v2)}')

print('\nCase 3:\n')
x1, v1, x2, v2 = 21, 6, 47, 3
print(f'{kangaroo(x1, v1, x2, v2)}')
# Out:
# Case 1:
#
# YES
#
# Case 2:
#
# NO
#
# Case 3:
#
# NO
