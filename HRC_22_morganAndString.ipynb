# %% [markdown]
# <a href="https://colab.research.google.com/github/AmirHosseinAlikhahMishamandani/Hackerrank/blob/main/HRC_22_morganAndString.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # hackerrank.com
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Solution

# %%
def morganAndString(a, b):
    a += "z"  # Append a character at the end of 'a' that is lexicographically greater than any character in the string
    b += "z"  # Do the same for 'b'
    i, j = 0, 0
    result = ""

    while i < len(a) - 1 or j < len(b) - 1:
        if a[i:] < b[j:]:
            result += a[i]
            i += 1
        else:
            result += b[j]
            j += 1

    return result




a = 'BBC'
b = 'BBA'
print(f'{morganAndString(a, b)}')

a = '...'
b = '...'

Sample = '...'

fun_out = morganAndString(a, b)
print(f'{True if fun_out == Sample else False}')

for idx in range(len(fun_out)):
  if Sample[idx] != fun_out[idx]:
    print(f'index {idx} and char fun_out {fun_out[idx]} and char Sample {Sample[idx]}')
    break
# Out:
# BBABBC
# True
